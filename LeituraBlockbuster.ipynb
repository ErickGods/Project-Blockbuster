# %%
# %pip install openpyxl
# Out:
# ...
#      -------------------------------------- 250.9/250.9 kB 3.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_csv('C:/Users/Erick/.cache/kagglehub/datasets/meetnagadia/blockbuster-movies-database-19752015/versions/1/blockbuster-top_ten_movies_per_year_DFE.csv')

# %%
df
# Out:
#      audience_freshness                                         poster_url  \
# 0                  92.0  http://resizing.flixster.com/gxRJwetP1eNIrPR6x...
# 1                  89.0  http://resizing.flixster.com/gDtbA1iPxTYEjBZeS...
# 2                  93.0  http://resizing.flixster.com/YrF_OeTQx3bXNsMLI...
# 3                  86.0  http://resizing.flixster.com/l9yjA-72sZMYECeOj...
# 4                  71.0  http://resizing.flixster.com/YukULOFULUesVZccN...
# ..                  ...                                                ...
# 394                60.0  http://resizing.flixster.com/XFNfAAKeokqanZJOB...
# 395                77.0  http://resizing.flixster.com/V6M1TKucdKIV1pTF3...
# 396                82.0  http://resizing.flixster.com/coMRFsl2YBbDwXYVs...
# 397                 NaN                                                NaN
# 398                67.0  http://resizing.flixster.com/cyLfP1xi9FRaJZSBo...
#
#      rt_audience_score  rt_freshness  rt_score 2015_inflation  \
# ...

# %%
df.to_excel('BlockBusterData.xlsx', index=False)
